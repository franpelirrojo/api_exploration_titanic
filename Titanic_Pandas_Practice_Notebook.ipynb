# %% [markdown]
# # 🧩 Titanic Dataset Exploration with pandas
#
# 🎯 **Goal:**
# In this notebook, you'll explore the Titanic dataset using **pandas**.
# You'll practice the most common pandas functions for data inspection, selection, filtering, cleaning, and analysis.
#
# For each function in the list below:
# 1. Explain what it does (in your own words, in a Markdown cell).
# 2. Give at least **two examples** using the Titanic dataset.
# 3. Add a short comment about the output or why it’s useful.

# %%
import pandas as pd

# Load Titanic dataset
# (Make sure titanic.csv is in the same folder as this notebook)
df = pd.read_csv("titanic_dataset.csv")

# %% [markdown]
# ## 🧠 Step 1: Inspecting the Data
#
# ### df.head() y df.tail()
# Estos métodos son útiles para extaer información del comienzo y el final de las series o dataframes respectivamente. Se usan para hacerse una idea rápida sobre un dataset. Harrison prefire usar `df.sample()` para hacerse una idea más real sobre los datos, ya que **las filas iniciales no suelen ser representativas**.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 524          525         0       3                      Kassem, Mr. Fared
# 851          852         0       3                    Svensson, Mr. Johan
# 37            38         0       3               Cann, Mr. Ernest Charles
# 72            73         0       2                   Hood, Mr. Ambrose Jr
# 246          247         0       3  Lindahl, Miss. Agda Thorilda Viktoria
#
#         Sex   Age  SibSp  Parch        Ticket     Fare Cabin Embarked
# 524    male   NaN      0      0          2700   7.2292   NaN        C
# 851    male  74.0      0      0        347060   7.7750   NaN        S
# 37     male  21.0      0      0    A./5. 2152   8.0500   NaN        S
# 72     male  21.0      0      0  S.O.C. 14879  73.5000   NaN        S
# 246  female  25.0      0      0        347071   7.7750   NaN        S

# %% [markdown]
# ### df.info()
# Imprime por la salida estandar información útil sobre el DataFrame en cuanto a estructura de datos: columnas, indices, tipos, tapaños etc. Un parametro importante es `memory_usage`.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 285.6 KB

# %% [markdown]
# ### df.describe()
# El método devuelve un DataFrame con información estadística de cada columna numérica, siendo pedantes, es una meta-agregación.

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### df.shape
# Devuelve una tupla con la dimensionalidad del DataFrame.

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### df.columns
# Este atributo devuelve las etiquetas de las columnas del DataFrame.

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## 🔍 Step 2: Selecting Data
# Las Series y los DataFrames en pandas implementan el operador de indexación de python `[]`, a la vez permiten indexar contra sus atributos `loc`y `ìloc`.

# %% [markdown]
# ### df["column"]
# Uno de los métodos para acceder a las columnas es indexarlas directamente desde el objeto. Igualmente podemos acceder a ellas directamente cómo un atributo, pero unicamente si el nombre de la columna es un nombre válido par aun atributo en python. **Muchas referencias recomiendan ignorar tanto las columnas cómo atributo cómo indexar directamente desde el objeto en favor de loc y iloc**.

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"] #Ambos devuelven una serie
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# El operador `[]` tiene un comportamiento diferente en Series y en DataFrames, en las series apela al indice mientras que en el Frame espera el nombre de una tabla.

# %%
#df[4] genera un error clave no encontrada
df["Age"][4]
# Out:
# np.float64(35.0)

# %% [markdown]
# Cuando indexamos una unica columna, podemos **forzar que nos devueva un DataFrame** indexando una lista en vez de un escalar.

# %%
df[["Age"]] #No podríamos indexar cómo arriba
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %% [markdown]
# Podmeos indexar más de una columna mediante una lista. Esta vez nos ha devuelto un dataframe no una serie, ya que tiene más de una columna
# .

# %%
df[["Age", "Sex"]]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %% [markdown]
# ### df.iloc[]
# El atributo iloc nos permite extraer filas y columnas mediante su posición.

# %%
df.iloc[4] #Es una Serie aunque es una fila!!!
# Out:
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 4, dtype: object

# %%
df.iloc[[4]] #Al indexar de nuevo sobre una lista, el objeto devuelto es un DataFrame
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
#
#    Parch  Ticket  Fare Cabin Embarked
# 4      0  373450  8.05   NaN        S

# %% [markdown]
# Al igual que en python, podemos pasarle un "slice" o incluso una función, que reciva un DataFrame y devuelva opciones válidas para `iloc`.

# %%
df.iloc[0:11:5]
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 0             1         0       3          Braund, Mr. Owen Harris    male
# 5             6         0       3                 Moran, Mr. James    male
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
#
#      Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0   22.0      1      0  A/5 21171   7.2500   NaN        S
# 5    NaN      0      0     330877   8.4583   NaN        Q
# 10   4.0      1      1    PP 9549  16.7000    G6        S

# %%
df.iloc[(lambda df:[0,5,10])]
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 0             1         0       3          Braund, Mr. Owen Harris    male
# 5             6         0       3                 Moran, Mr. James    male
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
#
#      Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0   22.0      1      0  A/5 21171   7.2500   NaN        S
# 5    NaN      0      0     330877   8.4583   NaN        Q
# 10   4.0      1      1    PP 9549  16.7000    G6        S

# %% [markdown]
# Y manteniendo la lógica de las operaciones anteriores, podemos extraer igualmente columnas.

# %%
df.iloc[:,[3]]
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %% [markdown]
# A pesar de su naturaleza posicional, `iloc` permite indexar mediante un array Numpy de booleanos. *Una serie de pandas, dará error*.

# %%
df.iloc[(df.Age>18).to_numpy()].sample(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 614          615         0       3  Brocklebank, Mr. William Alfred    male
# 379          380         0       3      Gustafsson, Mr. Karl Gideon    male
# 341          342         1       1   Fortune, Miss. Alice Elizabeth  female
# 296          297         0       3               Hanna, Mr. Mansour    male
# 188          189         0       3                 Bourke, Mr. John    male
#
#       Age  SibSp  Parch  Ticket      Fare        Cabin Embarked
# 614  35.0      0      0  364512    8.0500          NaN        S
# 379  19.0      0      0  347069    7.7750          NaN        S
# 341  24.0      3      2   19950  263.0000  C23 C25 C27        S
# 296  23.5      0      0    2693    7.2292          NaN        C
# 188  40.0      1      1  364849   15.5000          NaN        Q

# %% [markdown]
# ### df.loc[]
# El atributo loc nos permite indexar por el nombre del indice y de la columna. Es mportante recordar en este punto que los indices, aunque sean numericos autoincrementales, **son etiquetas no posiciones**.

# %%
df.loc[50:100:10, ["Name", "Sex", "Pclass"]]
# Out:
#                            Name     Sex  Pclass
# 50   Panula, Master. Juha Niilo    male       3
# 60        Sirayanian, Mr. Orsen    male       3
# 70   Jenkin, Mr. Stephen Curnow    male       2
# 80         Waelens, Mr. Achille    male       3
# 90         Christmann, Mr. Emil    male       3
# 100     Petranec, Miss. Matilda  female       3

# %% [markdown]
# `loc` puede indexar sobre un array de booleanos, es decir **una serie cuyo indice coincide con el del dataframe o la serie sobre la que se aplica la operación de indexado**,es más cómodo que `iloc`.

# %%
df.loc[df.Age>18].sample(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 197          198         0       3           Olsen, Mr. Karl Siegwart Andreas
# 288          289         1       2                       Hosono, Mr. Masabumi
# 577          578         1       1  Silvey, Mrs. William Baird (Alice Munger)
# 195          196         1       1                       Lurette, Miss. Elise
# 774          775         1       2      Hocking, Mrs. Elizabeth (Eliza Needs)
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 197    male  42.0      0      1      4579    8.4042   NaN        S
# 288    male  42.0      0      0    237798   13.0000   NaN        S
# 577  female  39.0      1      0     13507   55.9000   E44        S
# 195  female  58.0      0      0  PC 17569  146.5208   B80        C
# 774  female  54.0      1      3     29105   23.0000   NaN        S

# %% [markdown]
# Fijate que el comportamiento de `iloc` y `loc` al definir intervalos es diferente. `iloc` implementa una lógica de intervalo medio abierto, incluyendo el primer indice pero no el último; mientras que `loc`implementa un intervalo cerrado, incluyendo tanto el primer indice cómo el último. Hay excepciones cómo la indexación parcial que hace que esta lógica se sienta algo inconssitente.

# %%
df.iloc[50:100:10] #el mismo intervalo pero con iloc, observa la diferencia.
# Out:
#     PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 50           51         0       3  Panula, Master. Juha Niilo  male   7.0
# 60           61         0       3       Sirayanian, Mr. Orsen  male  22.0
# 70           71         0       2  Jenkin, Mr. Stephen Curnow  male  32.0
# 80           81         0       3        Waelens, Mr. Achille  male  22.0
# 90           91         0       3        Christmann, Mr. Emil  male  29.0
#
#     SibSp  Parch      Ticket     Fare Cabin Embarked
# 50      4      1     3101295  39.6875   NaN        S
# 60      0      0        2669   7.2292   NaN        C
# 70      0      0  C.A. 33111  10.5000   NaN        S
# 80      0      0      345767   9.0000   NaN        S
# 90      0      0      343276   8.0500   NaN        S

# %% [markdown]
# Podemos hacer indexación por rango en indices de strings, incluso podemos hacer una **indexación parcial**, pero los indices deben estar *ordenados*.

# %%
df.set_index("Embarked").sort_index().loc['C':'Q']
# Out:
#           PassengerId  Survived  Pclass                          Name     Sex  \
# Embarked
# C                 259         1       1              Ward, Miss. Anna  female
# C                 126         1       3  Nicola-Yarred, Master. Elias    male
# C                 355         0       3             Yousif, Mr. Wazli    male
# C                 353         0       3            Elias, Mr. Tannous    male
# C                 129         1       3             Peter, Miss. Anna  female
# ...               ...       ...     ...                           ...     ...
# Q                 209         1       3     Carr, Miss. Helen "Ellen"  female
# Q                 117         0       3          Connors, Mr. Patrick    male
# Q                 110         1       3           Moran, Miss. Bertha  female
# Q                  17         0       3          Rice, Master. Eugene    male
# Q                 127         0       3           McMahon, Mr. Martin    male
#
# ...

# %%
#Muy útil para seleccionar largas listas de nombres.Aquí extraemos los apellidos de la A a la C.
#Importante destacar que se la indexación parcial excluye el ultimo indice: los apellidos empezados por D no aparecen.
df.set_index('Name').sort_index().loc["A":"D", "PassengerId":"Pclass"]
# Out:
#                                                     PassengerId  Survived  \
# Name
# Abbing, Mr. Anthony                                         846         0
# Abbott, Mr. Rossmore Edward                                 747         0
# Abbott, Mrs. Stanton (Rosa Hunt)                            280         1
# Abelson, Mr. Samuel                                         309         0
# Abelson, Mrs. Samuel (Hannah Wizosky)                       875         1
# ...                                                         ...       ...
# Crosby, Capt. Edward Gifford                                746         0
# Crosby, Miss. Harriet R                                     541         1
# Culumovic, Mr. Jeso                                         845         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Cunningham, Mr. Alfred Fleming                              414         0
#
#                                                     Pclass
# Name
# ...

# %% [markdown]
# Puedes hacer indexación parcial de columnas si las ordenas.

# %%
df.set_index('Name').sort_index().sort_index(axis='columns').loc["A":"B", "P":"T"].head()
# Out:
#                                        Parch  PassengerId  Pclass     Sex  \
# Name
# Abbing, Mr. Anthony                        0          846       3    male
# Abbott, Mr. Rossmore Edward                1          747       3    male
# Abbott, Mrs. Stanton (Rosa Hunt)           1          280       3  female
# Abelson, Mr. Samuel                        0          309       2    male
# Abelson, Mrs. Samuel (Hannah Wizosky)      0          875       2  female
#
#                                        SibSp  Survived
# Name
# Abbing, Mr. Anthony                        0         0
# Abbott, Mr. Rossmore Edward                1         0
# Abbott, Mrs. Stanton (Rosa Hunt)           1         1
# Abelson, Mr. Samuel                        1         0
# Abelson, Mrs. Samuel (Hannah Wizosky)      1         1

# %% [markdown]
# ## 🔎 Step 3: Filtering Rows

# %% [markdown]
# Cómo se explicó en el apartado anterior vimos que es esposible filtrar una Serie o un DataFrame indexando con un array booleano. **Hay que tener cuidado a la hora de encadenar expresiones booleanas complejas ya que la precedencia puede generar un error no esperado.** En el ejemplo de abajo la expresión comentada generará un error ya que el operador `&`tine más precedencia que el operador `>`.

# %%
#df.loc[df.Age>18 & df.Sex == "female"].sample(5) -> Está evaluando df.loc[df.Age>(18 & df.Sex == "female")]
df.loc[df.Age>18 & (df.Sex == "female")].sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 549          550         1       2  Davies, Master. John Morgan Jr    male
# 56            57         1       2               Rugg, Miss. Emily  female
# 819          820         0       3    Skoog, Master. Karl Thorsten    male
# 252          253         0       1       Stead, Mr. William Thomas    male
# 515          516         0       1    Walker, Mr. William Anderson    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 549   8.0      1      1  C.A. 33112  36.7500   NaN        S
# 56   21.0      0      0  C.A. 31026  10.5000   NaN        S
# 819  10.0      3      2      347088  27.9000   NaN        S
# 252  62.0      0      0      113514  26.5500   C87        S
# 515  47.0      0      0       36967  34.0208   D46        S

# %% [markdown]
# ### df.query()
# El método `query`es único del DataFrame y permite realizar conultas complejas con un seudo sql.

# %%
max18=df["Age"]>18
df.query("@max18 and Sex == 'female'").sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 670          671         1       2
# 862          863         1       1
# 44            45         1       3
# 820          821         1       1
# 319          320         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 670  Brown, Mrs. Thomas William Solomon (Elizabeth ...  female  40.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 44                       Devaney, Miss. Margaret Delia  female  19.0      0
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  female  40.0      1
#
#      Parch  Ticket      Fare Cabin Embarked
# 670      1   29750   39.0000   NaN        S
# 862      0   17466   25.9292   D17        S
# 44       0  330958    7.8792   NaN        Q
# 820      1   12749   93.5000   B69        S
# 319      1   16966  134.5000   E34        C

# %% [markdown]
# ## 🧹 Step 4: Handling Missing Data
# Es común contar con información que falta al trabajar con conjuntos de datos, ya sea porque no existe, porque no se observó o porque se perdió. Pandas usa el valor float `NaN` y `NaT`para representar valores ausentes, aunque en algun dataset puede tener sus propios "valores centinelas".

# %% [markdown]
# ### df.isna()
# Devuelve una Serie o un DataFrame con el mismo indice y columnas que el original, pero cuyos valores son booleanos indicando si el valor es *NA(not available)* o no. El método `isnull` es un alias de `isna`.

# %%
df.isna().sum() #Sumamos los booleanos para ver cuantos NA hay en cada columna
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].isna
# Out:
# <bound method Series.isna of 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64>

# %% [markdown]
# ### df.dropna()
# Sirve para filtar los valores NA. Filtra sobre los nombres de los ejes dependiendo de si contienen o no valores nulos.Puede especificarse la cantidad de valores vacíos que se permiten para ser más precisos.

# %%
df.dropna().shape #unicamente 183 filas no tienen valores nulos
# Out:
# (183, 12)

# %%
df.dropna(how='all').shape #Podemos especificar que en vez de cualquier valor nulo, deban ser todos los valores nulos
# Out:
# (891, 12)

# %%
#Podemos específicar columans también
#thresh indica que la columna debe tener al menos 300 valores no nulos
df.dropna(thresh=300, axis=1).shape
# Out:
# (891, 11)

# %%
df.dropna(axis=1).sample() #Elimina las columnas con valores nulos
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex  SibSp  Parch  \
# 168          169         0       1  Baumann, Mr. John D  male      0      0
#
#        Ticket    Fare
# 168  PC 17318  25.925

# %% [markdown]
# ### df.fillna()
# A parte de descartar los NA, también podemos tratar de llenar los huecos.

# %%
df.fillna(18).info() #Usando un valor concreto
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Usando por ejemplo la media de la columna
#Al usarlo sobre una columna, lo estamos haciendo sobre una Serie, por lo que devolverá una Serie, no el DataFrame
df["Age"].fillna(df["Age"].median()).info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
df.fillna({'Age': 18, 'Embarked': 'C'}, inplace=True)#Usando un diccioanrio para un valor por columna
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## 📊 Step 5: Grouping and Aggregating

# %% [markdown]
# ### df.groupby
# Agrupar o pivotar la información permite convertir en tabla la expresión "obtener X por Y valor":
# - Colocar Y en el indice.
# - Una columna por cada valor de X.
# - Aplicar alguna transformación o de agregación si es necesario.
#
# Esta operación divide la información en grupos según el criterio dado y **devuelve un objeto lazy**, que no se calcula hasta que se le aplica una operación de transformación.
#
# ![Operación de agrupación](groupoperation.png)

# %%
# 1. Agrupamos por Edad y lugar de embarque.
# 2. Contamos el tipo de embarque para los valores de la tabla.
# 3. Usamos unstack para sacar el indice más a la derecha.
# 4. Rellenamos los NaN con ceros por presentación.
df.groupby(["Age", "Embarked"])["Embarked"].count().unstack().fillna(0.0)
# Out:
# Embarked    C    Q    S
# Age
# 0.42      1.0  0.0  0.0
# 0.67      0.0  0.0  1.0
# 0.75      2.0  0.0  0.0
# 0.83      0.0  0.0  2.0
# 0.92      0.0  0.0  1.0
# ...       ...  ...  ...
# 70.00     0.0  0.0  2.0
# 70.50     0.0  1.0  0.0
# 71.00     2.0  0.0  0.0
# 74.00     0.0  0.0  1.0
# 80.00     0.0  0.0  1.0
#
# [88 rows x 3 columns]

# %%
df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df["Fare"].mean() #Computa la media a lo largo de los valores de la columna.
# Out:
# np.float64(32.204207968574636)

# %%
df["Age"].median() #Computa la mediana a lo largo de los valores de la columna.
# Out:
# np.float64(24.0)

# %% [markdown]
# ## 📈 Step 6: Sorting and Counting

# %% [markdown]
# ### df.sort_vales()
# Podemos ordenar el DataFrame por sus valores. **Esta operación no altera el indice, aunque sea numérico**.

# %%
df.sort_values("Age", ascending=False).iloc[100:105] #ordenamos por edad de mayor a menor
# Out:
#      PassengerId  Survived  Pclass  \
# 789          790         0       1
# 331          332         0       1
# 203          204         0       3
# 187          188         1       1
# 276          277         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 789                       Guggenheim, Mr. Benjamin    male  46.0      0
# 331                            Partner, Mr. Austen    male  45.5      0
# 203                           Youseff, Mr. Gerious    male  45.5      0
# 187  Romaine, Mr. Charles Hallace ("Mr C Rolmane")    male  45.0      0
# 276              Lindblom, Miss. Augusta Charlotta  female  45.0      0
#
#      Parch    Ticket    Fare    Cabin Embarked
# 789      0  PC 17593  79.200  B82 B84        C
# 331      0    113043  28.500     C124        S
# 203      0      2628   7.225      NaN        C
# 187      0    111428  26.550      NaN        S
# 276      0    347073   7.750      NaN        S

# %% [markdown]
# ### s.unique() y s.value_counts
# Estos dos métodos forman parte de la clase de métodos que extraen información de una Serie unidimensional. `unique` devuelve un array con los valores únicos de la serie, por su parte, `value_counts` computa la frecuencia de los valores. A diferencia de `unique`, `value_counts` si que puede usarse en un DataFrame.

# %%
df["Embarked"].unique() #lo usamos sobre la columna
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    170
# Q     77
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                 Sex     Age   SibSp  Parch  Ticket    Fare     Cabin        Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0  1      0      PC 17599  71.2833  C85          C           1
# 4            1         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)         female  35.0  1      0      113803    53.1000  C123         S           1
# 7            0         1       McCarthy, Mr. Timothy J                              male    54.0  0      0      17463     51.8625  E46          S           1
# 11           1         3       Sandstrom, Miss. Marguerite Rut                      female  4.0   1      1      PP 9549   16.7000  G6           S           1
# 12           1         1       Bonnell, Miss. Elizabeth                             female  58.0  0      0      113783    26.5500  C103         S           1
# ...

# %% [markdown]
# ## ⚙️ Step 7: Creating or Modifying Columns

# %% [markdown]
# ### df[k]=v
# Podemos crear columnas nuevas siguiendo las lógicas de las listas y los diccionarios en python.

# %%
df["Fare_per_Age"] = df["Fare"] / df["Age"]
df[["Age", "Fare", "Fare_per_Age"]].head()
# Out:
#     Age     Fare  Fare_per_Age
# 0  22.0   7.2500      0.329545
# 1  38.0  71.2833      1.875876
# 2  26.0   7.9250      0.304808
# 3  35.0  53.1000      1.517143
# 4  35.0   8.0500      0.230000

# %% [markdown]
# ### df.assign
# Es una alternativa funcional a la asignación normal de columnas `df[k]=v`

# %%
df.assign(name_len=df["Name"].str.len()).sample(5)
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 639          640         0       3    Thorneycroft, Mr. Percival  male  18.0
# 204          205         1       3      Cohen, Mr. Gurshon "Gus"  male  18.0
# 228          229         0       2     Fahlstrom, Mr. Arne Jonas  male  18.0
# 405          406         0       2            Gale, Mr. Shadrach  male  34.0
# 734          735         0       2  Troupiansky, Mr. Moses Aaron  male  23.0
#
#      SibSp  Parch    Ticket   Fare Cabin Embarked  Fare_per_Age  name_len
# 639      1      0    376564  16.10   NaN        S      0.894444        26
# 204      0      0  A/5 3540   8.05   NaN        S      0.447222        24
# 228      0      0    236171  13.00   NaN        S      0.722222        25
# 405      1      0     28664  21.00   NaN        S      0.617647        18
# 734      0      0    233639  13.00   NaN        S      0.565217        28

# %% [markdown]
# ### df.apply
# Aplica una función sobre objetos unidimensionales, ya sean las columnas o la

# %%
def mayordeedad(x):
    if x > 18: return "Mayor de edad"
    return "Menor de edad"
df['Age'].apply(mayordeedad)
# Out:
# 0      Mayor de edad
# 1      Mayor de edad
# 2      Mayor de edad
# 3      Mayor de edad
# 4      Mayor de edad
#            ...
# 886    Mayor de edad
# 887    Mayor de edad
# 888    Menor de edad
# 889    Mayor de edad
# 890    Mayor de edad
# Name: Age, Length: 891, dtype: object

# %% [markdown]
# ### pd.concat
# A la hora de concatenar tablas o series en pandas hay muchas más variables a tneer en cuenta fruto de la abstracción del indice, pero a su vez permite una generalizaciónmayor de la concatenación. Pandas brinda una forma consistente de realizar esta operación mediante `concat`.

# %%
d1 = df["Age"]
d2 = df["Name"]
d3 = df["Sex"]

pd.concat([d1, d2, d3])[1]
# Out:
# 1                                                 38.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1                                               female
# dtype: object

# %%
pd.concat([d1, d2, d3], axis=1) #por defecto el eje es el indice, pero podemos unir cómo columnas
# Out:
#       Age                                               Name     Sex
# 0    22.0                            Braund, Mr. Owen Harris    male
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2    26.0                             Heikkinen, Miss. Laina  female
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4    35.0                           Allen, Mr. William Henry    male
# ..    ...                                                ...     ...
# 886  27.0                              Montvila, Rev. Juozas    male
# 887  19.0                       Graham, Miss. Margaret Edith  female
# 888  18.0           Johnston, Miss. Catherine Helen "Carrie"  female
# 889  26.0                              Behr, Mr. Karl Howell    male
# 890  32.0                                Dooley, Mr. Patrick    male
#
# [891 rows x 3 columns]

# %% [markdown]
# ### df.merge
# El método *merge* y el *join* permiten realizar uniones al estilo SQL, enlazando filas en base a una o más claves. Podemos especificar las columnas clave al igual que el tipo de join, por defecto es *inner*.

# %%
df1=df.loc[df.Age>18]
df2=df.loc[df.Sex=="male"]

#Al compartir el mismo indice, podemos realizar el merge directamente
pd.merge(df1, df2).sample(5).sort_index()
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 27            82         1       3           Sheerlinck, Mr. Jan Baptist
# 141          339         1       3                 Dahl, Mr. Karl Edwart
# 215          516         0       1          Walker, Mr. William Anderson
# 268          637         0       3            Leinonen, Mr. Antti Gustaf
# 370          868         0       1  Roebling, Mr. Washington Augustus II
#
#       Sex   Age  SibSp  Parch             Ticket     Fare Cabin Embarked  \
# 27   male  29.0      0      0             345779   9.5000   NaN        S
# 141  male  45.0      0      0               7598   8.0500   NaN        S
# 215  male  47.0      0      0              36967  34.0208   D46        S
# 268  male  32.0      0      0  STON/O 2. 3101292   7.9250   NaN        S
# 370  male  31.0      0      0           PC 17590  50.4958   A24        S
#
#      Fare_per_Age
# 27       0.327586
# 141      0.178889
# 215      0.723847
# ...

# %%
#Podemos igualmente especificar una clave, aunque en este ejemplo no tenga mucho sentido
pd.merge(df1, df2, on="Name", suffixes=('_Mayores', '_Masculino')).sample(5).sort_index()
# Out:
#      PassengerId_Mayores  Survived_Mayores  Pclass_Mayores  \
# 82                   198                 0               3
# 141                  339                 1               3
# 157                  378                 0               1
# 225                  549                 0               3
# 236                  576                 0               3
#
#                                  Name Sex_Mayores  Age_Mayores  SibSp_Mayores  \
# 82   Olsen, Mr. Karl Siegwart Andreas        male         42.0              0
# 141             Dahl, Mr. Karl Edwart        male         45.0              0
# 157         Widener, Mr. Harry Elkins        male         27.0              0
# 225         Goldsmith, Mr. Frank John        male         33.0              1
# 236              Patchett, Mr. George        male         19.0              0
#
#      Parch_Mayores Ticket_Mayores  Fare_Mayores  ... Pclass_Masculino  \
# ...

# %% [markdown]
# ## 💾 Step 8: Exporting Data
#
# Pandas implementa multiples funciones para exportar facilmente los dato a otros formatos, una de ellas es `df.to_csv`.

# %%
df.to_csv("titanic_cleaned.csv", index=False) #index false hace que no se guarden los nombres del indice

# %% [markdown]
# ## 🧩 Step 9: Summary
# Pandas se ha demostrado cómo una biblioteca muy grande, bastante más que numpy y empaquetando más complejidad. En este ejercicio he visto la importancia de conocer cual es la estrucutra interna de los DataFrame y cómo las Series son la estructura *básica de todas las operaciones*; si no se es consciente de esto, junto con la abstración de los indices, algunas lógicas parecen arbitrarias o inconsitentes. Otra caracteristica de Pandas que, creo ver venir de la própia filosofía de diseño de python, es lo poco ortogonal que es: ha mil formas de hacer una unica cosa.
#
# Métodos que más han destacado en esta exploración:
# - loc() y todas las diferentes formas de indexación.
# - groupby(), pivot_table() y las operaciones de agregación en general
# - assign(), concat(), apply() y los sabores funcionales de la biblioteca.
#
# ### Referencias
# - «API reference — pandas 2.3.3 documentation». Accedido 14 de noviembre de 2025. https://pandas.pydata.org/docs/reference/index.html.
# - Harrison, Matt. Effective Pandas 2: Opinionated Patterns for Data Manipulation. Treading on Python Series. Matt Harrison, 2024.
# - Hill, Christian. Learning Scientific Programming with Python. Second edition. Cambridge University Press, 2020.
# - McKinney, Wes. Python for Data Analysis: Data Wrangling with Pandas, NumPy, and IPython. Second edition, Fourth release. O’Reilly, 2018.
